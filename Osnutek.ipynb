# %% [markdown]
# # Uvod
# Nastavimo začetne parametre:

# %%
import pandas as pd
knjige = pd.read_csv('knjige.csv', index_col='id')
avtorji = pd.read_csv('avtorji.csv')
zanri = pd.read_csv('zanri.csv')
pd.options.display.max_rows = 20
# %matplotlib notebook

# %% [markdown]
# Razpredelnici s knjigami je treba odstraniti duplikate:

# %%
knjige = knjige.drop_duplicates(keep='first')
knjige
# Out:
#                                                      naslov  avtor_id  \
# id
# 1885                                    Pride and Prejudice      1265
# 10210                                             Jane Eyre   1036615
# 5297                             The Picture of Dorian Gray      3565
# 6185                                      Wuthering Heights      4191
# 7144                                   Crime and Punishment   3137322
# 35031085                                       Frankenstein     11139
# 7126                              The Count of Monte Cristo      4785
# 24213     Alice's Adventures in Wonderland &amp; Through...      8164
# 17245                                               Dracula      6988
# 24280                                        Les Misérables     13661
# ...                                                     ...       ...
# 40611999               Career of Evil (Cormoran Strike, #3)    383606
# 64081     The Irresistible Revolution: Living as an Ordi...     36103
# 30245      Cerulean Sins (Anita Blake, Vampire Hunter, #11)      9550
# 25373                  Nick &amp; Norah's Infinite Playlist     13139
# 153779                         Bloodhound (Beka Cooper, #2)      8596
# 295305    Wolf Brother (Chronicles of Ancient Darkness, #1)    119755
# 298568    Night of the Soul Stealer (The Last Apprentice...    146374
# 80631                                          Blood Memory     19696
# 234560    Time and Chance (Henry II &amp; Eleanor of Aqu...     24655
# 6481245             Shades of Midnight (Midnight Breed, #7)    375626
#
#                                 avtor  leto  ocena  st_ocen  st_kritik  \
# id
# 1885                      Jane Austen  1813   4.25  2465727      54575
# 10210                Charlotte Brontë  1847   4.11  1387282      34854
# 5297                      Oscar Wilde  1890   4.07   779572      23090
# 6185                     Emily Brontë  1847   3.84  1126057      29569
# 7144               Fyodor Dostoyevsky  1866   4.20   510326      14616
# 35031085  Mary Wollstonecraft Shelley  1818   3.77   978542      24345
# 7126                  Alexandre Dumas  1844   4.23   658188      17669
# 24213                   Lewis Carroll  1872   4.07   412252       9217
# 17245                     Bram Stoker  1897   3.98   779888      19981
# 24280                     Victor Hugo  1862   4.15   593608      13141
# ...                               ...   ...    ...      ...        ...
# 40611999             Robert Galbraith  2015   4.22   122225      12037
# 64081                 Shane Claiborne  2006   4.07    20382        975
# 30245             Laurell K. Hamilton  2003   3.84    45273        822
# 25373                     Rachel Cohn  2006   3.72    75301       4636
# 153779                  Tamora Pierce  2009   4.26    32926       1102
# 295305                 Michelle Paver  2004   4.16    19810       1363
# 298568                 Joseph Delaney  2007   4.13    24088        659
# 80631                       Greg Iles  2005   4.11    13529        858
# 234560              Sharon Kay Penman  2002   4.29     7180        331
# 6481245                   Lara Adrian  2009   4.28    24633        783
#
#           stoletje
# id
# 1885          1800
# 10210         1800
# 5297          1800
# 6185          1800
# 7144          1800
# 35031085      1800
# 7126          1800
# 24213         1800
# 17245         1800
# 24280         1800
# ...            ...
# 40611999      2000
# 64081         2000
# 30245         2000
# 25373         2000
# 153779        2000
# 295305        2000
# 298568        2000
# 80631         2000
# 234560        2000
# 6481245       2000
#
# [3494 rows x 8 columns]

# %% [markdown]
# Podatki so iz seznamov najboljših knjig 19., 20. in 21 stoletja, torej bi moralo biti število bralcev precejšnje. Gotovo je med njimi kakšna, ki si mesta ne zasluži.

# %%
slabe_knjige = knjige[(knjige.st_ocen < 20) & (knjige.st_kritik < 20)]
slabe_knjige.sort_values(by='st_ocen')
# Out:
#                                                      naslov  avtor_id  \
# id
# 17909028                    The Caves: Book One - The Event   7027588
# 13432288   The Gathering (The damnation Chronicles: Book 3)   1107101
# 21865943  Regular People of the Weak: A Rebel's Experien...   8128206
# 16123396      The Harbingers (The damnation Chronicles # 4)   1107101
# 13432285      Redemption (The Damnation Chronicles: book 2)   1107101
# 15992396  Take a Deep Breath - 21 Top Tips for Relaxed, ...   6520851
# 24985876  The Code: The Assiduous Quest of Tobias Hopkin...  13528752
# 23681340                                       Politixworks  10347331
# 26809568                         Valhalla (Colonization #4)   5375385
# 22038750                 The Founder's Curse (New Zigon #1)   8187644
# ...                                                     ...       ...
# 7984760          The Damned: Damnation Chronicles: Book One   1107101
# 34619565  Conscious Creativity; Mindfulness Meditations ...  13544944
# 25419982         Trueman Bradley - The Next Great Detective   5100743
# 26499472                       Black Hole (Colonization #2)   5375385
# 24985673  Homecoming: The Assiduous Quest of Tobias Hopk...  13528752
# 7307551                                  Moore's Mythopoeia    324097
# 18715583                                    Palette of Love   6549865
# 12260599              Huey Lambert's Walking Nuclear Circus   5077755
# 24351809  Kazungul: Blood Ties - Awakening of the Ancest...  12106810
# 22372232                                   Wildwood Shadows   5375385
#
#                           avtor  leto  ocena  st_ocen  st_kritik  stoletje
# id
# 17909028        Melody Laughlin  2013   5.00        7          1      2000
# 13432288           Joseph Sweet  2011   4.89        9          0      2000
# 21865943        Shareef Mabrouk  2014   4.78        9          0      2000
# 16123396           Joseph Sweet  2012   4.55       11          2      2000
# 13432285           Joseph Sweet  2010   4.67       12          0      2000
# 15992396          Michal Siwiec  2012   4.00       12          0      2000
# 24985876             James Faro  2015   4.92       12          3      2000
# 23681340        Chuck U. Farlie  2014   4.71       14          2      2000
# 26809568        Scott McElhaney  2015   4.53       15          0      2000
# 22038750  Danelle O&#39;Donnell  2014   4.07       15          6      2000
# ...                         ...   ...    ...      ...        ...       ...
# 7984760            Joseph Sweet  2007   3.94       17          3      2000
# 34619565   Nataša Nuit Pantović  2017   4.35       17          3      2000
# 25419982   Alexei Maxim Russell  2015   4.78       18          3      2000
# 26499472        Scott McElhaney  2015   4.17       18          1      2000
# 24985673             James Faro  2015   4.61       18          7      2000
# 7307551   Christopher WunderLee  2010   4.33       18          8      2000
# 18715583     Ashok  Kallarakkal  2013   4.00       19          8      2000
# 12260599        Jonathan Culver  2008   3.42       19          8      2000
# 24351809       Marcus L. Lukusa  2014   4.26       19          7      2000
# 22372232        Scott McElhaney  2014   4.37       19          0      2000
#
# [23 rows x 8 columns]

# %% [markdown]
# Ime, ki najbolj izstopa po pogostosti, je Joseph Sweet. Po krajši raziskavi se izkaže, da gre za avtorja, izdanega v samozaložbi, ki sam napiše večino svojih kritik. Njegovo mesto med "Najbolj priljubljenimi knjigami 21. stoletja" je tako vsekakor zelo sumljivo.

# %% [markdown]
# Poglejmo, kakšna je povprečna ocena vseh knjig (z drugimi besedami, kako prizanesljivi so uporabniki pri ocenjevanju), ter deset najslabše in najboljše ocenjenih knjig, pri čemer upoštevamo samo tiste, ki so prejele dovolj glasov.

# %%
knjige.ocena.mean()
# Out:
# 4.012469948483114

# %%
najboljše = knjige[(knjige.st_ocen > 10000) & (knjige.st_kritik > 5000)].sort_values(by='ocena', ascending=False)
najslabše = knjige[(knjige.st_ocen > 10000) & (knjige.st_kritik > 5000)].sort_values(by='ocena')
najboljše[:10]
# Out:
#                                                      naslov  avtor_id  \
# id
# 17332218     Words of Radiance (The Stormlight Archive, #2)     38550
# 862041     Harry Potter Series Box Set (Harry Potter, #1-7)   1077326
# 17927395  A Court of Mist and Fury (A Court of Thorns an...   3433047
# 7235533       The Way of Kings (The Stormlight Archive, #1)     38550
# 136251    Harry Potter and the Deathly Hallows (Harry Po...   1077326
# 22299763                 Crooked Kingdom (Six of Crows, #2)   4575289
# 18006496             Queen of Shadows (Throne of Glass, #4)   3433047
# 18335634      Clockwork Princess (The Infernal Devices, #3)    150038
# 1215032   The Wise Man's Fear (The Kingkiller Chronicle,...    108424
# 28260587             Empire of Storms (Throne of Glass, #5)   3433047
#
#                       avtor  leto  ocena  st_ocen  st_kritik  stoletje
# id
# 17332218  Brandon Sanderson  2014   4.77   142520       9129      2000
# 862041         J.K. Rowling  2007   4.74   222730       6869      2000
# 17927395      Sarah J. Maas  2016   4.69   199168      29384      2000
# 7235533   Brandon Sanderson  2010   4.65   210744      14019      2000
# 136251         J.K. Rowling  2007   4.62  2078115      57026      2000
# 22299763      Leigh Bardugo  2016   4.62    97807      15657      2000
# 18006496      Sarah J. Maas  2015   4.59   157774      17310      2000
# 18335634    Cassandra Clare  2013   4.59   278381      25450      2000
# 1215032    Patrick Rothfuss  2011   4.58   335098      18077      2000
# 28260587      Sarah J. Maas  2016   4.57   115910      15157      2000

# %% [markdown]
# Prav vse najbolje ocenjene knjige so napisane nedavno, kar seveda ni presenetljivo.

# %%
najslabše[:10]
# Out:
#                                                  naslov  avtor_id  \
# id
# 4929705                                 A Reliable Wife    266461
# 13497818                             The Casual Vacancy   1077326
# 24817626  Go Set a Watchman (To Kill a Mockingbird, #2)      1825
# 8573020                               The Weird Sisters    571131
# 12296                                The Scarlet Letter      7799
# 8366402                                The Tiger's Wife   4937879
# 228333                    The Nanny Diaries (Nanny, #1)      9222
# 4900                                  Heart of Darkness      3345
# 10964693                              The Marriage Plot      1467
# 5308                                          The Pearl       585
#
#                         avtor  leto  ocena  st_ocen  st_kritik  stoletje
# id
# 4929705       Robert Goolrick  2009   3.26    70900       9788      2000
# 13497818         J.K. Rowling  2012   3.29   275094      30060      2000
# 24817626           Harper Lee  2015   3.31   192026      26760      2000
# 8573020         Eleanor Brown  2011   3.36    41812       6180      2000
# 12296     Nathaniel Hawthorne  1850   3.38   614789      12725      1800
# 8366402            Téa Obreht  2011   3.38    79790      10011      2000
# 228333        Emma McLaughlin  2002   3.41   342272       5249      2000
# 4900            Joseph Conrad  1899   3.42   346162      11147      1800
# 10964693    Jeffrey Eugenides  2011   3.43   104932      11038      2000
# 5308           John Steinbeck  1947   3.44   163645       7080      1900

# %% [markdown]
# Tu so rezultati precej zanimivi. J. K. Rowling ima poleg najvišjih tudi enega od najnižjih rezultatov s svojo prvo knjigo, ki ni iz serije o Harryju Potterju. Prav to je najbrž razlog, da je uvrščena tako nizko. Na seznamu najdemo tudi Go Set a Watchman, ki jo je Harper Lee napisala pod pritiskom svoje založbe in je bila kritično zelo slabo sprejeta, in pa The Scarlet Letter, ki je pogosto obvezno branje v angleško govorečem svetu. Več o kontroverznih avtorjih in šolski literaturi pa v razdelkih 2 in 3.

# %% [markdown]
# Glede na to, da so zajeti seznami knjig 19., 20. in 21. stoletja, nas seveda zanima, katero stoletje je med bralci najbolj priljubljeno:

# %%
knjige['stoletje'] = 100 * (knjige.leto // 100)
knjige.groupby('stoletje').ocena.mean()
# Out:
# stoletje
# 1700    4.110000
# 1800    3.904938
# 1900    4.048725
# 2000    4.012287
# Name: ocena, dtype: float64

# %% [markdown]
# Opazimo, da je očitno na seznamu tudi kakšna knjiga, ki vanj ne spada. Vidimo tudi, da so vsa stoletja razen 21. pod povprečno oceno. So pa očitno najmanj priljubljene knjige iz 19. stoletja; več o tem v naslednjem poglavju.

# %% [markdown]
# Kaj pa najboljša knjiga iz posameznega stoletja?

# %%
trojka = knjige.groupby('stoletje')['ocena'].max()
trojka
# Out:
# stoletje
# 1700    4.11
# 1800    4.48
# 1900    4.75
# 2000    5.00
# Name: ocena, dtype: float64

# %% [markdown]
# # Analiza žanrov

# %% [markdown]
# Razpredelnica žanri vsebuje precej žanrov na posamezno knjigo, veliko se jih tako pojavi samo nekajkrat:

# %%
popularnost_žanrov = zanri.stack().value_counts()

# %% [markdown]
# Prikažimo nekaj najbolj pogostih žanrov z grafom.

# %%
popularnost_žanrov[popularnost_žanrov > 300].plot(kind='pie', title='Popularnost žanrov')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Združimo tabeli za žanri in ostalimi podatki o knjigah, da bomo lahko pogledali podatke glede na posamezen žanr.

# %%
zdruzen = pd.merge(zanri, knjige, right_on = 'id', left_on = 'knjiga')
zdruzen
# Out:
#         knjiga               zanr  \
# 0         1885           classics
# 1         1885            fiction
# 2         1885            romance
# 3        10210           classics
# 4        10210            fiction
# 5        10210            romance
# 6        10210  historicalfiction
# 7        10210         literature
# 8        10210             gothic
# 9        10210         historical
# ...        ...                ...
# 16803    80631           suspense
# 16804   234560  historicalfiction
# 16805   234560            fiction
# 16806   234560         historical
# 16807   234560           medieval
# 16808   234560  britishliterature
# 16809  6481245  paranormalromance
# 16810  6481245         paranormal
# 16811  6481245           vampires
# 16812  6481245            romance
#
#                                                   naslov  avtor_id  \
# 0                                    Pride and Prejudice      1265
# 1                                    Pride and Prejudice      1265
# 2                                    Pride and Prejudice      1265
# 3                                              Jane Eyre   1036615
# 4                                              Jane Eyre   1036615
# 5                                              Jane Eyre   1036615
# 6                                              Jane Eyre   1036615
# 7                                              Jane Eyre   1036615
# 8                                              Jane Eyre   1036615
# 9                                              Jane Eyre   1036615
# ...                                                  ...       ...
# 16803                                       Blood Memory     19696
# 16804  Time and Chance (Henry II &amp; Eleanor of Aqu...     24655
# 16805  Time and Chance (Henry II &amp; Eleanor of Aqu...     24655
# 16806  Time and Chance (Henry II &amp; Eleanor of Aqu...     24655
# 16807  Time and Chance (Henry II &amp; Eleanor of Aqu...     24655
# 16808  Time and Chance (Henry II &amp; Eleanor of Aqu...     24655
# 16809            Shades of Midnight (Midnight Breed, #7)    375626
# 16810            Shades of Midnight (Midnight Breed, #7)    375626
# 16811            Shades of Midnight (Midnight Breed, #7)    375626
# 16812            Shades of Midnight (Midnight Breed, #7)    375626
#
#                    avtor  leto  ocena  st_ocen  st_kritik
# 0            Jane Austen  1813   4.25  2465727      54575
# 1            Jane Austen  1813   4.25  2465727      54575
# 2            Jane Austen  1813   4.25  2465727      54575
# 3       Charlotte Brontë  1847   4.11  1387282      34854
# 4       Charlotte Brontë  1847   4.11  1387282      34854
# 5       Charlotte Brontë  1847   4.11  1387282      34854
# 6       Charlotte Brontë  1847   4.11  1387282      34854
# 7       Charlotte Brontë  1847   4.11  1387282      34854
# 8       Charlotte Brontë  1847   4.11  1387282      34854
# 9       Charlotte Brontë  1847   4.11  1387282      34854
# ...                  ...   ...    ...      ...        ...
# 16803          Greg Iles  2005   4.11    13529        858
# 16804  Sharon Kay Penman  2002   4.29     7180        331
# 16805  Sharon Kay Penman  2002   4.29     7180        331
# 16806  Sharon Kay Penman  2002   4.29     7180        331
# 16807  Sharon Kay Penman  2002   4.29     7180        331
# 16808  Sharon Kay Penman  2002   4.29     7180        331
# 16809        Lara Adrian  2009   4.28    24633        783
# 16810        Lara Adrian  2009   4.28    24633        783
# 16811        Lara Adrian  2009   4.28    24633        783
# 16812        Lara Adrian  2009   4.28    24633        783
#
# [16813 rows x 9 columns]

# %% [markdown]
# Kakšne so povprečne ocene po žanrih, ki se pojavijo dovolj pogosto?

# %%
pogostost_zanrov = zanri.groupby('zanr').size().to_frame('pogostost')
ocene_po_zanrih = zdruzen.groupby('zanr').ocena.mean()
povprecna_na_zanr = pd.concat([ocene_po_zanrih, pogostost_zanrov], axis=1)
povprecna = povprecna_na_zanr.sort_values('pogostost', ascending= False)
povprecna
# Out:
#                            ocena  pogostost
# zanr
# fiction                 3.982066       2604
# classics                3.986161       1311
# fantasy                 4.077440        838
# historicalfiction       4.001708        726
# literature              3.945661        599
# youngadult              4.049336        532
# romance                 4.020565        494
# nonfiction              4.073432        475
# mystery                 3.975849        369
# contemporary            3.878732        339
# ...                          ...        ...
# holidaywishlist         4.710000          1
# highratedongoodreads44  4.880000          1
# roadtrip                4.210000          1
# harunyahya              4.080000          1
# hardlyknownbooks        4.710000          1
# regency                 4.170000          1
# halloween               3.810000          1
# greece                  4.010000          1
# goth                    4.110000          1
# رمانایرانی              4.680000          1
#
# [449 rows x 2 columns]

# %% [markdown]
# Narišimo graf žanrov z najboljšimi ocenami, seveda le, če se žanri dovolj pogosto pojavijo.

# %%
ocena_zanra = povprecna_na_zanr.sort_values('ocena')
ocena_zanra[ocena_zanra.pogostost > 300].ocena.plot(kind='bar', title='Povprečna ocena na žanr')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Graf ni preveč zgovoren, vse povprečne ocene se gibljejo nekje okoli 4. Pričakovano je najbolje ocenjen žanr "fantasy": skoraj vse najbolje ocenjene knjige iz uvoda so bile iz tega žanra.

# %% [markdown]
# Morda bi bilo zanimivo tudi pogledati, kateri žanri privabijo največ participacije v obliki kritik.

# %%
kritike_po_zanrih = zdruzen.groupby('zanr').st_kritik.mean()
kritike_na_zanr = pd.concat([kritike_po_zanrih, pogostost_zanrov], axis=1)
kritike = kritike_na_zanr.sort_values('pogostost', ascending= False)
kritike
# Out:
#                            st_kritik  pogostost
# zanr
# fiction                  5986.503049       2604
# classics                 4083.128475       1311
# fantasy                  7971.583333        838
# historicalfiction        5861.486339        726
# literature               4526.712887        599
# youngadult              13344.479705        532
# romance                  9324.620968        494
# nonfiction               3794.909474        475
# mystery                  6103.140162        369
# contemporary             9568.663717        339
# ...                              ...        ...
# holidaywishlist             2.000000          1
# highratedongoodreads44      6.000000          1
# roadtrip                    4.000000          1
# harunyahya                  2.000000          1
# hardlyknownbooks            2.000000          1
# regency                  2594.000000          1
# halloween                  52.000000          1
# greece                   2271.000000          1
# goth                       15.000000          1
# رمانایرانی                 16.000000          1
#
# [449 rows x 2 columns]

# %%
kritike_zanra = kritike_na_zanr.sort_values(by='st_kritik', ascending=False)
kritike_zanra[kritike_zanra.pogostost > 300].st_kritik.plot(kind='barh', title='Kritike na žanr')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# opomba: tu moraš še upoštevati pogostost posameznega žanra.

# %% [markdown]
# Tu pa zelo očitno izstopa "youngadult".

# %% [markdown]
# Za konec pa si še oglejmo, kako se povprečna ocena in število kritik žanra "school" primerjata z ostalimi.

# %%
ocene_po_zanrih['school']
# Out:
# 3.8228000000000004

# %%
kritike_po_zanrih['school']
# Out:
# 18071.986666666668

# %% [markdown]
# # Analiza avtorjev

# %% [markdown]
# Kateri avtorji so najbolj priljubljeni mad bralci?

# %%
najboljši = knjige[knjige.st_ocen > 10000].groupby(['avtor_id', 'avtor']).ocena.mean()
najboljši.sort_values(ascending=False)[:20]
# Out:
# avtor_id  avtor
# 13778     Bill Watterson       4.683333
# 108424    Patrick Rothfuss     4.565000
# 15049422  Angie Thomas         4.560000
# 6492      Francine Rivers      4.553333
# 7816      Fernando Pessoa      4.480000
# 28709     Chuck Dixon          4.480000
# 5158478   Anonymous            4.480000
# 3433047   Sarah J. Maas        4.472500
# 500       Jorge Luis Borges    4.472500
# 5804101   Anthony Ryan         4.460000
# 1943477   Kathryn Stockett     4.460000
# 20411     Lawrence Hill        4.450000
# 4859212   R.J. Palacio         4.450000
# 38550     Brandon Sanderson    4.442857
# 24824     Jon Stone            4.440000
# 722       Robert A. Caro       4.430000
# 17434     Alex Haley           4.430000
# 12425     Robert Kirkman       4.430000
# 785914    Barbara Demick       4.430000
# 5117      Art Spiegelman       4.420000
# Name: ocena, dtype: float64

# %% [markdown]
# Zdaj pa nas zanimajo najbolj kontroverzni avtorji, torej tisti z veliko kritikami, ki imajo najnižje ocene.

# %%
kontroverzni= knjige[knjige.st_kritik > 25000].groupby(['avtor_id', 'avtor']).ocena.mean()
kontroverzni.sort_values()[:20]
# Out:
# avtor_id  avtor
# 11679     Elizabeth Gilbert     3.530000
# 306       William Golding       3.660000
# 941441    Stephenie Meyer       3.664000
# 1304470   Ally Condie           3.670000
# 5042201   John Tiffany          3.700000
# 15481463  William Paul Young    3.750000
# 316       Alice Sebold          3.790000
# 4725841   E.L. James            3.796667
# 630       Dan Brown             3.797500
# 819789    J.D. Salinger         3.800000
# 4280      Kazuo Ishiguro        3.810000
# 173491    E. Lockhart           3.840000
# 4191      Emily Brontë          3.840000
# 566       Paulo Coelho          3.840000
# 383606    Robert Galbraith      3.850000
# 585       John Steinbeck        3.850000
# 1050      Mark Haddon           3.860000
# 811       Yann Martel           3.890000
# 8719      Donna Tartt           3.890000
# 3046613   Ransom Riggs          3.900000
# Name: ocena, dtype: float64

# %% [markdown]
# Očitno so parametri precej ustrezno izbrani glede na pojavitev Stephenie Meyer, E. L. James in Dana Browna.

# %%
produktivnost_avtorjev = knjige.groupby(['avtor_id', 'avtor']).size().to_frame('produktivnost')
produktivni = produktivnost_avtorjev.sort_values('produktivnost', ascending=False)
produktivni[:20]
# Out:
#                              produktivnost
# avtor_id avtor
# 3389     Stephen King                   40
# 4624490  Edgar Allan Poe                23
# 1654     Terry Pratchett                21
# 3137322  Fyodor Dostoyevsky             18
# 1069006  C.S. Lewis                     17
# 20524    Anthony Trollope               17
# 15872    Rick Riordan                   16
# 1221698  Neil Gaiman                    15
# 239579   Charles Dickens                15
# 3565     Oscar Wilde                    14
# 2778055  Kurt Vonnegut                  14
# 4750     Émile Zola                     13
# 5375385  Scott McElhaney                13
# 17061    Charlaine Harris               13
# 3354     Haruki Murakami                13
# 5091     Lee Child                      12
# 2345     Nicholas Sparks                12
# 5350     L.M. Montgomery                11
# 4785     Alexandre Dumas                11
# 10746    Jim Butcher                    11

# %% [markdown]
# ocene produktivnih + graf
